# %% [markdown]
# # Week 1 Lab: Python Basics & Data Structures
#
# **Estimated Time:** 30-60 minutes
# **Objective:** Review Python fundamentals and data structures essential for data analytics.
#
# In this lab, you will:
# - Work with Python lists, dictionaries, and comprehensions
# - Practice NumPy array operations
# - Get comfortable with Pandas DataFrames
#
# ---

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd

print("✓ Libraries imported!")

# %% [markdown]
# ---
# ## Part 1: Python Lists and Dictionaries
#
# **Scenario:** Working with Philippine city data

# %% [markdown]
# ### Exercise 1.1: List Operations

# %%
# Philippine cities and their populations (in millions)
cities = ['Manila', 'Quezon City', 'Caloocan', 'Davao', 'Cebu City']
populations = [1.78, 2.96, 1.66, 1.78, 0.96]

# TODO: Find the city with the largest population
max_pop_index = None  # Your code here
largest_city = None   # Your code here

print(f"Largest city: {largest_city}")

# TODO: Calculate average population
avg_pop = None  # Your code here
print(f"Average population: {avg_pop:.2f}M")

# TODO: Filter cities with population > 1.5M using list comprehension
large_cities = []  # Your code here
print(f"Cities with pop > 1.5M: {large_cities}")

# %% [markdown]
# ### Exercise 1.2: Dictionary Operations

# %%
# TODO: Create a dictionary mapping cities to populations
city_data = {}  # Your code here (use zip or dict comprehension)

print(f"City data dictionary: {city_data}")

# TODO: Add a new city
# Your code here: add 'Taguig' with population 0.88M

# TODO: Get population of Davao City
davao_pop = None  # Your code here
print(f"Davao City population: {davao_pop}M")

# %% [markdown]
# ---
# ## Part 2: NumPy Arrays
#
# **Background:** NumPy is faster than lists for numerical operations

# %% [markdown]
# ### Exercise 2.1: Array Creation and Operations

# %%
# Monthly temperatures in Cebu (°C)
temps = [27.2, 27.5, 28.1, 29.0, 29.5, 29.2, 28.8, 28.5, 28.3, 28.0, 27.8, 27.4]

# TODO: Convert to NumPy array
temps_array = None  # Your code here

# TODO: Calculate mean, max, min temperatures
mean_temp = None  # Your code here
max_temp = None   # Your code here
min_temp = None   # Your code here

print(f"Mean: {mean_temp:.1f}°C")
print(f"Max: {max_temp:.1f}°C")
print(f"Min: {min_temp:.1f}°C")

# TODO: Find months where temp > 28.5°C
hot_months = None  # Your code here (boolean indexing)
print(f"Hot months (>28.5°C): {hot_months}")

# %% [markdown]
# ### Exercise 2.2: Array Arithmetic

# %%
# Convert Celsius to Fahrenheit: F = (C * 9/5) + 32
# TODO: Convert the entire temps_array to Fahrenheit
temps_fahrenheit = None  # Your code here

print(f"Temperatures in Fahrenheit:")
print(temps_fahrenheit)

# %% [markdown]
# ---
# ## Part 3: Pandas DataFrames
#
# **Background:** Pandas is the go-to library for data manipulation in Python

# %% [markdown]
# ### Exercise 3.1: Create and Explore DataFrame

# %%
# Philippine university data
data = {
    'University': ['UP Diliman', 'UP Cebu', 'Ateneo', 'DLSU', 'UST'],
    'Students': [23000, 4500, 12000, 15000, 40000],
    'Founded': [1908, 1977, 1859, 1911, 1611],
    'City': ['Quezon City', 'Cebu City', 'Quezon City', 'Manila', 'Manila']
}

# TODO: Create DataFrame
df = None  # Your code here

# TODO: Display first 3 rows
# Your code here

# TODO: Display basic info (columns, types, non-null counts)
# Your code here

# %% [markdown]
# ### Exercise 3.2: Data Selection and Filtering

# %%
# TODO: Get the 'Students' column
students = None  # Your code here
print(f"Student counts:\n{students}")

# TODO: Filter universities in Quezon City
qc_unis = None  # Your code here
print(f"\nQuezon City universities:\n{qc_unis}")

# TODO: Filter universities founded before 1900
old_unis = None  # Your code here
print(f"\nUniversities founded before 1900:\n{old_unis}")

# %% [markdown]
# ### Exercise 3.3: Aggregation

# %%
# TODO: Calculate total students across all universities
total_students = None  # Your code here
print(f"Total students: {total_students:,}")

# TODO: Find average founding year
avg_year = None  # Your code here
print(f"Average founding year: {avg_year:.0f}")

# TODO: Group by City and sum Students
students_by_city = None  # Your code here
print(f"\nStudents by city:\n{students_by_city}")

# %% [markdown]
# ---
# ## Reflection Questions
#
# 1. **Why NumPy?** When would you use NumPy arrays instead of Python lists?
#
# 2. **Pandas vs NumPy:** What advantages does Pandas offer over NumPy for data analysis?
#
# 3. **Real-world Application:** How could you use these data structures to analyze Philippine economic data?

# %% [markdown]
# ### Your Answers:
#
# **Answer 1:**
# [Your answer here]
#
# **Answer 2:**
# [Your answer here]
#
# **Answer 3:**
# [Your answer here]

# %% [markdown]
# ---
#
# ## 🎯 Congratulations!
#
# You've completed Week 1 Lab on Python Basics & Data Structures.
#
# **Key Skills Practiced:**
# - Python lists, dictionaries, and comprehensions
# - NumPy array operations and vectorization
# - Pandas DataFrame creation, filtering, and aggregation
#
# **Remember:** Check the **solution notebook** if you need help!
#
# **Next Steps:**
# - Practice more with Philippine datasets
# - Review Pandas documentation
# - Move on to Week 2 lab (Probability & Statistical Testing)
#
# ---
#
# *CMSC 178DA - Data Analytics | University of the Philippines Cebu*
